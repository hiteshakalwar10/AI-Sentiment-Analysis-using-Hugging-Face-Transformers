# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
result = classifier("I love learning AI!")
print(result)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9996976852416992}]

# %%
classifier("The movie was okay.")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998013377189636}]

# %%
classifier("i hate this movie")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9996687173843384}]

# %%
import os
os.listdir("/content")
# Out:
# ['.config',
#  'AI-Sentiment-Analysis-using-Hugging-Face-Transformers',
#  'sample_data']

# %%
import json

path = "sentiment_analyzer.ipynb"  # match your actual Colab filename — check with the code below if unsure
with open(path) as f:
    nb = json.load(f)
nb.get("metadata", {}).pop("widgets", None)
with open(path, "w") as f:
    json.dump(nb, f, indent=1)
